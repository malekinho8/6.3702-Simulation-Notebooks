# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
n = 100
X = np.random.uniform(0,1,(100000,n))
Y = np.sum(X,axis=1)

# %%
Y.shape
# Out:
# (100000,)

# %%
plt.hist(Y,bins=100)
plt.show()
