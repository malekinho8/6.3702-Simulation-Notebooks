# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
out = []
N = 10000
for n in range(N):
  num_dates = 0
  bob_late = 0
  while bob_late < 2:
    A = 9
    B = np.random.uniform(8,10)
    X = B - 9
    if X >= 0.5:
      bob_late += 1
    num_dates += 1
  out.append(num_dates)

# %%
np.mean(out)
# Out:
# 7.9677
